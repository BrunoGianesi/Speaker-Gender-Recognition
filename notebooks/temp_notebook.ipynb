# %%
import pandas as pd
import os

# %%
dataset = 'CommonVoice'
project_root = os.path.dirname(os.getcwd())
dataset = pd.read_csv(f'{project_root}/data/{dataset}/MFCCs_data.csv')

# %%
dataset[dataset['Gender'] == 1]
# Out:
#                           FileName     MFCC_1      MFCC_2     MFCC_3  \
# 0     common_voice_pt_19564750.wav -414.16638   55.246174 -20.121910
# 1     common_voice_pt_19547806.wav -386.30283   62.420654 -28.707080
# 2     common_voice_pt_21663026.wav -283.15268  119.714700   0.409852
# 3     common_voice_pt_19435786.wav -362.03200   75.147354 -36.256687
# 4     common_voice_pt_20523845.wav -331.72100  110.255640  -4.318350
# ...                            ...        ...         ...        ...
# 6380  common_voice_pt_20523676.wav -343.33057  140.152620 -15.513513
# 6381  common_voice_pt_20473567.wav -396.06958   95.083100  -3.990336
# 6382  common_voice_pt_19441121.wav -395.91500   48.443466 -30.724964
# 6383  common_voice_pt_19331464.wav -511.43690  103.815790   1.765876
# 6384  common_voice_pt_21830948.wav -316.73505   85.612404  11.200121
#
#          MFCC_4     MFCC_5     MFCC_6     MFCC_7     MFCC_8     MFCC_9  ...  \
# ...

# %%
263*2
# Out:
# 526
