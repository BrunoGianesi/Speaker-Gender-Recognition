# %% [markdown]
# # Imports:

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

import os
import librosa
import asyncio
import numpy as np
import pandas as pd
import scipy.stats as stats
import time
import nest_asyncio
#from speechpy import feature
#import aiofiles
import time
import parselmouth

# %% [markdown]
# # Extract frequency features:

# %% [markdown]
# ## Get Metadata

# %%
project_root =  os.path.dirname(os.path.dirname(os.getcwd()))
CVFolder = os.path.join(project_root, "CommonVoice-En")

source = os.path.join(project_root, 'CommonVoice-En', 'Full')
files = os.listdir(source)

test = pd.read_csv(os.path.join(CVFolder, "test.tsv"), delimiter="	")
test = test[(test.gender == 'male') | (test.gender == 'female')]

train = pd.read_csv(os.path.join(CVFolder, "train.tsv"), delimiter="	")
train = train[(train.gender == 'male') | (train.gender == 'female')]

validated = pd.read_csv(os.path.join(CVFolder, "validated.tsv"), delimiter="	")
validated = validated[(validated.gender == 'male') | (validated.gender == 'female')]

final = pd.concat([test, train,validated])

fem_final = final[(final.gender == 'female')]
fem_final = fem_final[:1000]
male_final = final[(final.gender == 'male')]
male_final = male_final[:1000]
final = pd.concat([fem_final, male_final])

files_without_wav = [file.replace('.wav', '') for file in files]

df = final[final['path'].isin(files_without_wav)].reset_index()
df
# Out:
#      index                                          client_id  \
# 0        8  01dc88c61ec0eb8f22ab6ee768fb1f13780f2869f70336...
# 1       83  0c00d476cc4b12f5c7b751412871a725f548c05315241a...
# 2      340  369ebdcea5e434ee2261477f9ebf862cd5aeac002541cb...
# 3      500  53def0cb62cb696817d35356fcdea8850ca5bdbfbea29d...
# 4      835  8f759eb1f4d42a9161c6f1235122b6ca5d5f3e9c3c383b...
# ..     ...                                                ...
# 794    970  a3e9ba570eff338be233bf5795fb62d030f535631fedac...
# 795    973  a3e9ba570eff338be233bf5795fb62d030f535631fedac...
# 796    974  a3e9ba570eff338be233bf5795fb62d030f535631fedac...
# 797    975  a3e9ba570eff338be233bf5795fb62d030f535631fedac...
# 798    976  a3e9ba570eff338be233bf5795fb62d030f535631fedac...
#
#                                                   path  \
# 0    2f8392c2dfa63d2a7fdfebc053f9eff02246387575e205...
# 1    33f6f6793f00ed68593ce9560406006e7c9693faacccbb...
# 2    06c73d5731753b0f9accd4b68494a7b677ba8db954c7f9...
# 3    52b40bf55615a1a76458fafa29e1225c0bed5b7df0f3a4...
# 4    48081fddb6fe56d7238739344274f98f70f4a4335f37fc...
# ..                                                 ...
# 794  2afa3d37e26d4c0abccf567c24431dba4094eb3d012bea...
# 795  3382f58c3e8268ef8196df2dd123a5be9c87542f33a68f...
# 796  3775fea31d0de1fe21deb3c11d363df0776d606878adb9...
# 797  4ff1fdee808c24ac5caf5c020c3d8d6cca47f0b5d8e075...
# 798  13bf7dc8e51955c3061d23d79a43b0ce3a2b154d1fe273...
#
#                                               sentence  up_votes  down_votes  \
# 0                       We couldn't make it in a week!         2           1
# 1                        I promise, I will be careful!         2           0
# 2    Vermicelli A trio, or musical piece for three ...         2           0
# 3             Plastic surgery has become more popular.         2           0
# 4                                   I'm going to them.         3           0
# ..                                                 ...       ...         ...
# 794  Some men are standing around a grill as some a...         2           0
# 795  A woman riding a blue bike is carrying a white...         3           0
# 796               Two men skateboarding in the forest.         2           0
# 797                      Two people talking on a dock.         2           0
# 798  A crowd of variously attired people is walking...         2           0
#
#           age  gender   accent
# 0    fourties  female       us
# 1       teens  female    other
# 2    twenties  female       us
# 3    fourties  female       us
# 4    twenties  female  england
# ..        ...     ...      ...
# 794  twenties    male       us
# 795  twenties    male       us
# 796  twenties    male       us
# 797  twenties    male       us
# 798  twenties    male       us
#
# [799 rows x 9 columns]

# %% [markdown]
# ## Extract features:

# %%
async def get_frequencies(count, row, file):
    file_path = os.path.join(project_root,"CommonVoice-En", "Full", file)

    if row.gender == 'male': 
        gender = 1
    if row.gender == 'female':
        gender = 0

    audio_data = parselmouth.Sound(file_path)
    audio_data = audio_data.values[0]
    sample_rate = 16000
    
    step = int(sample_rate/5) #3200 sampling points every 1/5 sec
    window_frequencies = []

    for i in range(0,len(audio_data),step):
        ft = np.fft.fft(audio_data[i:i+step]) #fft returns the list N complex numbers
        freqs = librosa.fft_frequencies(sr=16000, n_fft=len(ft))
        freqs = np.fft.fftfreq(len(ft)) #fftq tells you the frequencies associated with the coefficients
        imax = np.argmax(np.abs(ft))
        freq = freqs[imax]
        freq_in_hz = abs(freq *sample_rate)
        window_frequencies.append(freq_in_hz)

    return window_frequencies, gender, file

# %%
async def get_features(count, row):
    async with sem:
        file = row.path + '.wav'
        frequencies, gender, file_name = await get_frequencies(count, row, file)

        nobs, minmax, mean, variance, skew, kurtosis =  stats.describe(frequencies)
        median   = np.median(frequencies)
        mode     = stats.mode(frequencies).mode[0]
        std      = np.std(frequencies)
        low,peak = minmax
        q75,q25  = np.percentile(frequencies, [75 ,25])
        iqr      = q75 - q25

        features_list.append([file_name, nobs, mean, skew, kurtosis, median, mode, std, low, peak, q25, q75, iqr, gender])
        print(f"\r{count}/{len(df)}", end='')

        return nobs, mean, skew, kurtosis, median, mode, std, low, peak, q25, q75, iqr

# %%
# #Calculo de tempo de disparo
start_time = time.time()

#inicio do Loop
loop = asyncio.get_event_loop()

#Controle de requisições por vez
sem = asyncio.Semaphore(2000)

#Array de tasks
sents = []

nest_asyncio.apply()

#Coleta as recomendações para envio
gender_list = []
file_list = []
features_list = []

for k, row in df.iterrows():
     sent = asyncio.ensure_future(get_features(count=k+1, row=row))

# done, _ = loop.run_until_complete(asyncio.wait(sents))
# Out:
# female
# 1/799female
# 2/799female
# 3/799female
# 4/799female
# 5/799female
# 6/799female
# 7/799female
# 8/799female
# 9/799female
# 10/799female
# 11/799female
# 12/799female
# 13/799female
# 14/799female
# 15/799female
# 16/799female
# 17/799female
# 18/799female
# 19/799female
# 20/799female
# 21/799female
# 22/799female
# 23/799female
# 24/799female
# 25/799female
# 26/799female
# 27/799female
# 28/799female
# 29/799female
# 30/799female
# 31/799female
# 32/799female
# 33/799female
# 34/799female
# 35/799female
# 36/799female
# 37/799female
# 38/799female
# 39/799female
# 40/799female
# 41/799female
# 42/799female
# 43/799female
# 44/799female
# 45/799female
# 46/799female
# 47/799female
# 48/799female
# 49/799female
# 50/799female
# 51/799female
# 52/799female
# 53/799female
# 54/799female
# 55/799female
# 56/799female
# 57/799female
# 58/799female
# 59/799female
# 60/799female
# 61/799female
# 62/799female
# 63/799female
# 64/799female
# 65/799female
# 66/799female
# 67/799female
# 68/799female
# 69/799female
# 70/799female
# 71/799female
# 72/799female
# 73/799female
# 74/799female
# 75/799female
# 76/799female
# 77/799female
# 78/799female
# 79/799female
# 80/799female
# 81/799female
# 82/799female
# 83/799female
# 84/799female
# 85/799female
# 86/799female
# 87/799female
# 88/799female
# 89/799female
# 90/799female
# 91/799female
# 92/799female
# 93/799female
# 94/799female
# 95/799female
# 96/799female
# 97/799female
# 98/799female
# 99/799female
# 100/799female
# 101/799female
# 102/799female
# 103/799female
# 104/799female
# 105/799female
# 106/799female
# 107/799female
# 108/799female
# 109/799female
# 110/799female
# 111/799female
# 112/799female
# 113/799female
# 114/799female
# 115/799female
# 116/799female
# 117/799female
# 118/799female
# 119/799female
# 120/799female
# 121/799female
# 122/799female
# 123/799female
# 124/799female
# 125/799female
# 126/799female
# 127/799female
# 128/799female
# 129/799female
# 130/799female
# 131/799female
# 132/799female
# 133/799female
# 134/799female
# 135/799female
# 136/799female
# 137/799female
# 138/799female
# 139/799female
# 140/799female
# 141/799female
# 142/799female
# 143/799female
# 144/799female
# 145/799female
# 146/799female
# 147/799female
# 148/799female
# 149/799female
# 150/799female
# 151/799female
# 152/799female
# 153/799female
# 154/799female
# 155/799female
# 156/799female
# 157/799female
# 158/799female
# 159/799female
# 160/799female
# 161/799female
# 162/799female
# 163/799female
# 164/799female
# 165/799female
# 166/799female
# 167/799female
# 168/799female
# 169/799female
# 170/799female
# 171/799female
# 172/799female
# 173/799female
# 174/799female
# 175/799female
# 176/799female
# 177/799female
# 178/799female
# 179/799female
# 180/799female
# 181/799female
# 182/799female
# 183/799female
# 184/799female
# 185/799female
# 186/799female
# 187/799female
# 188/799female
# 189/799female
# 190/799female
# 191/799female
# 192/799female
# 193/799female
# 194/799female
# 195/799female
# 196/799female
# 197/799female
# 198/799female
# 199/799female
# 200/799female
# 201/799female
# 202/799female
# 203/799female
# 204/799female
# 205/799female
# 206/799female
# 207/799female
# 208/799female
# 209/799female
# 210/799female
# 211/799female
# 212/799female
# 213/799female
# 214/799female
# 215/799female
# 216/799female
# 217/799female
# 218/799female
# 219/799female
# 220/799female
# 221/799female
# 222/799female
# 223/799female
# 224/799female
# 225/799female
# 226/799female
# 227/799female
# 228/799female
# 229/799female
# 230/799female
# 231/799female
# 232/799female
# 233/799female
# 234/799female
# 235/799female
# 236/799female
# 237/799female
# 238/799female
# 239/799female
# 240/799female
# 241/799female
# 242/799female
# 243/799female
# 244/799female
# 245/799female
# 246/799female
# 247/799female
# 248/799female
# 249/799female
# 250/799female
# 251/799female
# 252/799female
# 253/799female
# 254/799female
# 255/799female
# 256/799female
# 257/799female
# 258/799female
# 259/799female
# 260/799female
# 261/799female
# 262/799female
# 263/799female
# 264/799female
# 265/799female
# 266/799female
# 267/799female
# 268/799female
# 269/799female
# 270/799female
# 271/799female
# 272/799female
# 273/799female
# 274/799female
# 275/799female
# 276/799female
# 277/799female
# 278/799female
# 279/799female
# 280/799female
# 281/799female
# 282/799female
# 283/799female
# 284/799female
# 285/799female
# 286/799female
# 287/799female
# 288/799female
# 289/799female
# 290/799female
# 291/799female
# 292/799female
# 293/799female
# 294/799female
# 295/799female
# 296/799female
# 297/799female
# 298/799female
# 299/799female
# 300/799female
# 301/799female
# 302/799female
# 303/799female
# 304/799female
# 305/799female
# 306/799female
# 307/799female
# 308/799female
# 309/799female
# 310/799female
# 311/799female
# 312/799female
# 313/799female
# 314/799female
# 315/799female
# 316/799female
# 317/799female
# 318/799female
# 319/799female
# 320/799female
# 321/799female
# 322/799female
# 323/799female
# 324/799female
# 325/799female
# 326/799female
# 327/799female
# 328/799female
# 329/799female
# 330/799female
# 331/799female
# 332/799female
# 333/799female
# 334/799female
# 335/799female
# 336/799female
# 337/799female
# 338/799female
# 339/799female
# 340/799female
# 341/799female
# 342/799female
# 343/799female
# 344/799female
# 345/799female
# 346/799female
# 347/799female
# 348/799female
# 349/799female
# 350/799female
# 351/799female
# 352/799female
# 353/799female
# 354/799female
# 355/799female
# 356/799female
# 357/799female
# 358/799female
# 359/799female
# 360/799female
# 361/799female
# 362/799female
# 363/799female
# 364/799female
# 365/799female
# 366/799female
# 367/799female
# 368/799female
# 369/799female
# 370/799female
# 371/799female
# 372/799female
# 373/799female
# 374/799female
# 375/799female
# 376/799female
# 377/799female
# 378/799female
# 379/799female
# 380/799female
# 381/799female
# 382/799female
# 383/799female
# 384/799female
# 385/799female
# 386/799female
# 387/799female
# 388/799female
# 389/799female
# 390/799female
# 391/799female
# 392/799female
# 393/799female
# 394/799female
# 395/799female
# 396/799female
# 397/799female
# 398/799female
# 399/799female
# 400/799female
# 401/799female
# 402/799female
# 403/799female
# 404/799female
# 405/799female
# 406/799female
# 407/799female
# 408/799male
# 409/799male
# 410/799male
# 411/799male
# 412/799male
# 413/799male
# 414/799male
# 415/799male
# 416/799male
# 417/799male
# 418/799male
# 419/799male
# 420/799male
# 421/799male
# 422/799male
# 423/799male
# 424/799male
# 425/799male
# 426/799male
# 427/799male
# 428/799male
# 429/799male
# 430/799male
# 431/799male
# 432/799male
# 433/799male
# 434/799male
# 435/799male
# 436/799male
# 437/799male
# 438/799male
# 439/799male
# 440/799male
# 441/799male
# 442/799male
# 443/799male
# 444/799male
# 445/799male
# 446/799male
# 447/799male
# 448/799male
# 449/799male
# 450/799male
# 451/799male
# 452/799male
# 453/799male
# 454/799male
# 455/799male
# 456/799male
# 457/799male
# 458/799male
# 459/799male
# 460/799male
# 461/799male
# 462/799male
# 463/799male
# 464/799male
# 465/799male
# 466/799male
# 467/799male
# 468/799male
# 469/799male
# 470/799male
# 471/799male
# 472/799male
# 473/799male
# 474/799male
# 475/799male
# 476/799male
# 477/799male
# 478/799male
# 479/799male
# 480/799male
# 481/799male
# 482/799male
# 483/799male
# 484/799male
# 485/799male
# 486/799male
# 487/799male
# 488/799male
# 489/799male
# 490/799male
# 491/799male
# 492/799male
# 493/799male
# 494/799male
# 495/799male
# 496/799male
# 497/799male
# 498/799male
# 499/799male
# 500/799male
# 501/799male
# 502/799male
# 503/799male
# 504/799male
# 505/799male
# 506/799male
# 507/799male
# 508/799male
# 509/799male
# 510/799male
# 511/799male
# 512/799male
# 513/799male
# 514/799male
# 515/799male
# 516/799male
# 517/799male
# 518/799male
# 519/799male
# 520/799male
# 521/799male
# 522/799male
# 523/799male
# 524/799male
# 525/799male
# 526/799male
# 527/799male
# 528/799male
# 529/799male
# 530/799male
# 531/799male
# 532/799male
# 533/799male
# 534/799male
# 535/799male
# 536/799male
# 537/799male
# 538/799male
# 539/799male
# 540/799male
# 541/799male
# 542/799male
# 543/799male
# 544/799male
# 545/799male
# 546/799male
# 547/799male
# 548/799male
# 549/799male
# 550/799male
# 551/799male
# 552/799male
# 553/799male
# 554/799male
# 555/799male
# 556/799male
# 557/799male
# 558/799male
# 559/799male
# 560/799male
# 561/799male
# 562/799male
# 563/799male
# 564/799male
# 565/799male
# 566/799male
# 567/799male
# 568/799male
# 569/799male
# 570/799male
# 571/799male
# 572/799male
# 573/799male
# 574/799male
# 575/799male
# 576/799male
# 577/799male
# 578/799male
# 579/799male
# 580/799male
# 581/799male
# 582/799male
# 583/799male
# 584/799male
# 585/799male
# 586/799male
# 587/799male
# 588/799male
# 589/799male
# 590/799male
# 591/799male
# 592/799male
# 593/799male
# 594/799male
# 595/799male
# 596/799male
# 597/799male
# 598/799male
# 599/799male
# 600/799male
# 601/799male
# 602/799male
# 603/799male
# 604/799male
# 605/799male
# 606/799male
# 607/799male
# 608/799male
# 609/799male
# 610/799male
# 611/799male
# 612/799male
# 613/799male
# 614/799male
# 615/799male
# 616/799male
# 617/799male
# 618/799male
# 619/799male
# 620/799male
# 621/799male
# 622/799male
# 623/799male
# 624/799male
# 625/799male
# 626/799male
# 627/799male
# 628/799male
# 629/799male
# 630/799male
# 631/799male
# 632/799male
# 633/799male
# 634/799male
# 635/799male
# 636/799male
# 637/799male
# 638/799male
# 639/799male
# 640/799male
# 641/799male
# 642/799male
# 643/799male
# 644/799male
# 645/799male
# 646/799male
# 647/799male
# 648/799male
# 649/799male
# 650/799male
# 651/799male
# 652/799male
# 653/799male
# 654/799male
# 655/799male
# 656/799male
# 657/799male
# 658/799male
# 659/799male
# 660/799male
# 661/799male
# 662/799male
# 663/799male
# 664/799male
# 665/799male
# 666/799male
# 667/799male
# 668/799male
# 669/799male
# 670/799male
# 671/799male
# 672/799male
# 673/799male
# 674/799male
# 675/799male
# 676/799male
# 677/799male
# 678/799male
# 679/799male
# 680/799male
# 681/799male
# 682/799male
# 683/799male
# 684/799male
# 685/799male
# 686/799male
# 687/799male
# 688/799male
# 689/799male
# 690/799male
# 691/799male
# 692/799male
# 693/799male
# 694/799male
# 695/799male
# 696/799male
# 697/799male
# 698/799male
# 699/799male
# 700/799male
# 701/799male
# 702/799male
# 703/799male
# 704/799male
# 705/799male
# 706/799male
# 707/799male
# 708/799male
# 709/799male
# 710/799male
# 711/799male
# 712/799male
# 713/799male
# 714/799male
# 715/799male
# 716/799male
# 717/799male
# 718/799male
# 719/799male
# 720/799male
# 721/799male
# 722/799male
# 723/799male
# 724/799male
# 725/799male
# 726/799male
# 727/799male
# 728/799male
# 729/799male
# 730/799male
# 731/799male
# 732/799male
# 733/799male
# 734/799male
# 735/799male
# 736/799male
# 737/799male
# 738/799male
# 739/799male
# 740/799male
# 741/799male
# 742/799male
# 743/799male
# 744/799male
# 745/799male
# 746/799male
# 747/799male
# 748/799male
# 749/799male
# 750/799male
# 751/799male
# 752/799male
# 753/799male
# 754/799male
# 755/799male
# 756/799male
# 757/799male
# 758/799male
# 759/799male
# 760/799male
# 761/799male
# 762/799male
# 763/799male
# 764/799male
# 765/799male
# 766/799male
# 767/799male
# 768/799male
# 769/799male
# 770/799male
# 771/799male
# 772/799male
# 773/799male
# 774/799male
# 775/799male
# 776/799male
# 777/799male
# 778/799male
# 779/799male
# 780/799male
# 781/799male
# 782/799male
# 783/799male
# 784/799male
# 785/799male
# 786/799male
# 787/799male
# 788/799male
# 789/799male
# 790/799male
# 791/799male
# 792/799male
# 793/799male
# 794/799male
# 795/799male
# 796/799male
# 797/799male
# 798/799male
# 799/799

# %%
dataframe_features = pd.DataFrame(features_list, columns = ['FileName', 'nobs', 'mean', 'skew', 'kurtosis', 'median', 'mode', 'std', 'low', 'peak', 'q25', 'q75', 'iqr', 'Gender'])
dataframe_features
# Out:
#                                               FileName  nobs        mean  \
# 0    2f8392c2dfa63d2a7fdfebc053f9eff02246387575e205...    66  102.348485
# 1    33f6f6793f00ed68593ce9560406006e7c9693faacccbb...   103  230.026294
# 2    06c73d5731753b0f9accd4b68494a7b677ba8db954c7f9...   103  651.933657
# 3    52b40bf55615a1a76458fafa29e1225c0bed5b7df0f3a4...   112  337.172619
# 4    48081fddb6fe56d7238739344274f98f70f4a4335f37fc...    44  139.550395
# ..                                                 ...   ...         ...
# 794  2afa3d37e26d4c0abccf567c24431dba4094eb3d012bea...    89  179.213483
# 795  3382f58c3e8268ef8196df2dd123a5be9c87542f33a68f...    80  119.812500
# 796  3775fea31d0de1fe21deb3c11d363df0776d606878adb9...    45  201.777778
# 797  4ff1fdee808c24ac5caf5c020c3d8d6cca47f0b5d8e075...    48   78.307292
# 798  13bf7dc8e51955c3061d23d79a43b0ce3a2b154d1fe273...   112  161.175595
#
#          skew   kurtosis  median   mode          std   low    peak    q25  \
# 0    4.147523  18.221901    50.0   45.0   137.119224   0.0   890.0  45.00
# 1    2.706938   6.621953   105.0   95.0   316.039870  15.0  1660.0  85.00
# 2    2.526111   6.171771   145.0   90.0  1096.607296   0.0  5115.0  90.00
# 3    2.990574   9.371681   212.5  400.0   444.804824   0.0  2195.0  98.75
# 4    6.348443  38.547236    75.0   70.0   351.816990  50.0  2440.0  70.00
# ..        ...        ...     ...    ...          ...   ...     ...    ...
# 794  2.796121   6.124384    35.0   15.0   423.069242   0.0  1715.0  15.00
# 795  4.037067  16.370266    42.5   15.0   279.340119   0.0  1575.0  20.00
# 796  2.466445   4.207987    40.0   20.0   434.972739   0.0  1540.0  20.00
# 797  5.805409  34.608072    22.5   20.0   209.769294   0.0  1445.0  15.00
# 798  3.342740  10.746279    40.0   35.0   355.769597   0.0  2000.0  23.75
#
#         q75     iqr  Gender
# 0    108.75   63.75       0
# 1    180.00   95.00       0
# 2    795.00  705.00       0
# 3    400.00  301.25       0
# 4     95.00   25.00       0
# ..      ...     ...     ...
# 794   50.00   35.00       1
# 795   70.00   50.00       1
# 796   75.00   55.00       1
# 797   45.00   30.00       1
# 798   70.00   46.25       1
#
# [799 rows x 14 columns]

# %%
dataframe_features.to_csv('D:\dev\Speaker-Gender-Recognition\data\CommonVoice-En/Features_data.csv', index=False)

# %% [markdown]
# # Get MFCCs

# %% [markdown]
# ## Get Metadata

# %%
project_root =  os.path.dirname(os.path.dirname(os.getcwd()))
CVFolder = os.path.join(project_root, "CommonVoice-En")

source = os.path.join(project_root, 'CommonVoice-En', 'Full')
files = os.listdir(source)

test = pd.read_csv(os.path.join(CVFolder, "test.tsv"), delimiter="	")
test = test[(test.gender == 'male') | (test.gender == 'female')]

train = pd.read_csv(os.path.join(CVFolder, "train.tsv"), delimiter="	")
train = train[(train.gender == 'male') | (train.gender == 'female')]

validated = pd.read_csv(os.path.join(CVFolder, "validated.tsv"), delimiter="	")
validated = validated[(validated.gender == 'male') | (validated.gender == 'female')]

final = pd.concat([test, train,validated])

fem_final = final[(final.gender == 'female')]
fem_final = fem_final[:1000]
male_final = final[(final.gender == 'male')]
male_final = male_final[:1000]
final = pd.concat([fem_final, male_final])

files_without_wav = [file.replace('.wav', '') for file in files]

df = final[final['path'].isin(files_without_wav)].reset_index()
df
# Out:
#      index                                          client_id  \
# 0        8  01dc88c61ec0eb8f22ab6ee768fb1f13780f2869f70336...
# 1       83  0c00d476cc4b12f5c7b751412871a725f548c05315241a...
# 2      340  369ebdcea5e434ee2261477f9ebf862cd5aeac002541cb...
# 3      500  53def0cb62cb696817d35356fcdea8850ca5bdbfbea29d...
# 4      835  8f759eb1f4d42a9161c6f1235122b6ca5d5f3e9c3c383b...
# ..     ...                                                ...
# 794    970  a3e9ba570eff338be233bf5795fb62d030f535631fedac...
# 795    973  a3e9ba570eff338be233bf5795fb62d030f535631fedac...
# 796    974  a3e9ba570eff338be233bf5795fb62d030f535631fedac...
# 797    975  a3e9ba570eff338be233bf5795fb62d030f535631fedac...
# 798    976  a3e9ba570eff338be233bf5795fb62d030f535631fedac...
#
#                                                   path  \
# 0    2f8392c2dfa63d2a7fdfebc053f9eff02246387575e205...
# 1    33f6f6793f00ed68593ce9560406006e7c9693faacccbb...
# 2    06c73d5731753b0f9accd4b68494a7b677ba8db954c7f9...
# 3    52b40bf55615a1a76458fafa29e1225c0bed5b7df0f3a4...
# 4    48081fddb6fe56d7238739344274f98f70f4a4335f37fc...
# ..                                                 ...
# 794  2afa3d37e26d4c0abccf567c24431dba4094eb3d012bea...
# 795  3382f58c3e8268ef8196df2dd123a5be9c87542f33a68f...
# 796  3775fea31d0de1fe21deb3c11d363df0776d606878adb9...
# 797  4ff1fdee808c24ac5caf5c020c3d8d6cca47f0b5d8e075...
# 798  13bf7dc8e51955c3061d23d79a43b0ce3a2b154d1fe273...
#
#                                               sentence  up_votes  down_votes  \
# 0                       We couldn't make it in a week!         2           1
# 1                        I promise, I will be careful!         2           0
# 2    Vermicelli A trio, or musical piece for three ...         2           0
# 3             Plastic surgery has become more popular.         2           0
# 4                                   I'm going to them.         3           0
# ..                                                 ...       ...         ...
# 794  Some men are standing around a grill as some a...         2           0
# 795  A woman riding a blue bike is carrying a white...         3           0
# 796               Two men skateboarding in the forest.         2           0
# 797                      Two people talking on a dock.         2           0
# 798  A crowd of variously attired people is walking...         2           0
#
#           age  gender   accent
# 0    fourties  female       us
# 1       teens  female    other
# 2    twenties  female       us
# 3    fourties  female       us
# 4    twenties  female  england
# ..        ...     ...      ...
# 794  twenties    male       us
# 795  twenties    male       us
# 796  twenties    male       us
# 797  twenties    male       us
# 798  twenties    male       us
#
# [799 rows x 9 columns]

# %% [markdown]
# ## Extract MFCCs

# %%
async def extract_MFCCs(count, row):
    async with sem:
        file = row.path + '.wav'

        file_path = os.path.join(project_root,"CommonVoice-En", "Full", file)

        if row.gender == 'female':
            gender = 0
        if row.gender == 'male': 
            gender = 1
        
        audio_data = parselmouth.Sound(file_path)
        audio_data = audio_data.values[0]
        sample_rate = 16000
        
        mfccs = librosa.feature.mfcc(y=audio_data, sr=sample_rate)
        
        mfccs_mean = list(np.mean(mfccs.T, axis= 0))
        
        sample_features = mfccs_mean
        sample_features.insert(0,str(file))
        sample_features.append(gender)
        
        print(f"\r{count}/{len(df)}",end='')
        features_list.append(sample_features)
    
        return

# %%
# #Calculo de tempo de disparo
start_time = time.time()

#inicio do Loop
loop = asyncio.get_event_loop()

#Controle de requisições por vez
sem = asyncio.Semaphore(600)

#Array de tasks
sents = []

nest_asyncio.apply()

#Coleta as recomendações para envio
gender_list = []
file_list = []
features_list = []

for k, row in df.iterrows():
        sent = asyncio.ensure_future(extract_MFCCs(count=k+1, row=row))
#         sents.append(sent)
 
# done, _ = loop.run_until_complete(asyncio.wait(sents))
# Out:
# 799/799

# %%
dataframe_features = pd.DataFrame(features_list, columns = ['FileName','MFCC_1','MFCC_2','MFCC_3','MFCC_4','MFCC_5',
                                                            'MFCC_6','MFCC_7','MFCC_8','MFCC_9','MFCC_10','MFCC_11',
                                                            'MFCC_12','MFCC_13','MFCC_14','MFCC_15','MFCC_16','MFCC_17',
                                                            'MFCC_18','MFCC_19','MFCC_20','Gender'])
dataframe_features
# Out:
#                                               FileName      MFCC_1  \
# 0    2f8392c2dfa63d2a7fdfebc053f9eff02246387575e205... -408.913274
# 1    33f6f6793f00ed68593ce9560406006e7c9693faacccbb... -338.503637
# 2    06c73d5731753b0f9accd4b68494a7b677ba8db954c7f9... -455.740432
# 3    52b40bf55615a1a76458fafa29e1225c0bed5b7df0f3a4... -484.662055
# 4    48081fddb6fe56d7238739344274f98f70f4a4335f37fc... -354.570978
# ..                                                 ...         ...
# 794  2afa3d37e26d4c0abccf567c24431dba4094eb3d012bea... -386.263630
# 795  3382f58c3e8268ef8196df2dd123a5be9c87542f33a68f... -394.255766
# 796  3775fea31d0de1fe21deb3c11d363df0776d606878adb9... -396.111007
# 797  4ff1fdee808c24ac5caf5c020c3d8d6cca47f0b5d8e075... -406.443017
# 798  13bf7dc8e51955c3061d23d79a43b0ce3a2b154d1fe273... -395.572155
#
#          MFCC_2     MFCC_3     MFCC_4     MFCC_5     MFCC_6     MFCC_7  \
# 0     92.802238  24.222945  21.564401   0.837400  20.131803   4.406617
# 1    146.092735   1.907427 -12.908492  33.085521  33.898751  -1.440834
# 2     77.141277   4.925703  14.756924  13.384630  34.220768   4.420631
# 3     82.932846  -5.790933  -5.898868  15.347033   3.785266  -1.394950
# 4     76.553183  25.357306  11.706292  14.841730  11.357447   8.998382
# ..          ...        ...        ...        ...        ...        ...
# 794  120.371827   5.352067  28.265075  -5.130548  26.342742   5.820971
# 795  133.201820   8.429066  41.176245  -9.144433  30.214971   0.939496
# 796  129.581651   1.125031  42.453387  -9.490710  31.725901  13.995674
# 797  102.721273   9.219459  25.019276   2.174081  22.180863   4.808151
# 798  140.410772   7.895240  35.880124  -5.852087  32.537438  12.095711
#
#         MFCC_8     MFCC_9  ...   MFCC_12    MFCC_13    MFCC_14    MFCC_15  \
# 0     8.008858   8.173683  ...  2.465940   5.942938   0.313347   3.104217
# 1   -11.088388   1.965735  ... -1.213857   3.551892  -5.383912 -10.387132
# 2     3.191059  10.809214  ... -2.791192  -7.731319  -8.188610   3.202001
# 3     4.707987   0.150487  ...  8.818200   1.674253  -3.287812  -7.106608
# 4     9.299078   6.971776  ...  1.853223   0.308829  -2.777751  -6.462977
# ..         ...        ...  ...       ...        ...        ...        ...
# 794   0.027935   1.957019  ...  1.974348   8.326172   2.741778   7.063979
# 795   6.002862  12.723422  ...  6.096548  11.915752 -10.176714   4.880812
# 796  -3.001004   5.215216  ...  2.052305   6.906460  -4.149303   8.000287
# 797   2.660074   2.931871  ...  6.019701   8.432873  -7.251087   3.890966
# 798  -1.680448   4.222121  ...  5.594449   6.302117  -7.528352   4.242444
#
#        MFCC_16    MFCC_17   MFCC_18    MFCC_19   MFCC_20  Gender
# 0    -2.834497  -0.554444  1.736628   0.561705  1.665345       0
# 1    -1.989165   2.685330 -2.035855  -5.382838  0.166376       0
# 2     0.105393  -7.219017 -6.251872  -3.729273  0.017557       0
# 3    -8.278183  -2.637173  0.688595  -3.859376 -4.317977       0
# 4    -5.243096  -1.656487 -1.738631  -2.810475 -1.947313       0
# ..         ...        ...       ...        ...       ...     ...
# 794  10.189332  -2.652470 -0.551666   3.843953  1.325541       1
# 795   7.115240  -3.316691  6.399162   2.597431 -1.501949       1
# 796   9.208161  -8.589908 -0.724473   8.975612  1.855020       1
# 797   5.462469  -0.590436  5.690388   7.703315  2.319307       1
# 798   4.101325 -11.055470  7.979992  11.354431 -2.456268       1
#
# [799 rows x 22 columns]

# %%
dataframe_features.to_csv('D:\dev\Speaker-Gender-Recognition\data\CommonVoice-En/MFCCs_data.csv', index=False)

# %% [markdown]
# # Get F0

# %% [markdown]
# ## Extract Metadata

# %%
project_root =  os.path.dirname(os.path.dirname(os.getcwd()))
CVFolder = os.path.join(project_root, "CommonVoice-En")

source = os.path.join(project_root, 'CommonVoice-En', 'Full')
files = os.listdir(source)

test = pd.read_csv(os.path.join(CVFolder, "test.tsv"), delimiter="	")
test = test[(test.gender == 'male') | (test.gender == 'female')]

train = pd.read_csv(os.path.join(CVFolder, "train.tsv"), delimiter="	")
train = train[(train.gender == 'male') | (train.gender == 'female')]

validated = pd.read_csv(os.path.join(CVFolder, "validated.tsv"), delimiter="	")
validated = validated[(validated.gender == 'male') | (validated.gender == 'female')]

final = pd.concat([test, train,validated])

fem_final = final[(final.gender == 'female')]
fem_final = fem_final[:1000]
male_final = final[(final.gender == 'male')]
male_final = male_final[:1000]
final = pd.concat([fem_final, male_final])

files_without_wav = [file.replace('.wav', '') for file in files]

df = final[final['path'].isin(files_without_wav)].reset_index()
df
# Out:
#      index                                          client_id  \
# 0        8  01dc88c61ec0eb8f22ab6ee768fb1f13780f2869f70336...
# 1       83  0c00d476cc4b12f5c7b751412871a725f548c05315241a...
# 2      340  369ebdcea5e434ee2261477f9ebf862cd5aeac002541cb...
# 3      500  53def0cb62cb696817d35356fcdea8850ca5bdbfbea29d...
# 4      835  8f759eb1f4d42a9161c6f1235122b6ca5d5f3e9c3c383b...
# ..     ...                                                ...
# 794    970  a3e9ba570eff338be233bf5795fb62d030f535631fedac...
# 795    973  a3e9ba570eff338be233bf5795fb62d030f535631fedac...
# 796    974  a3e9ba570eff338be233bf5795fb62d030f535631fedac...
# 797    975  a3e9ba570eff338be233bf5795fb62d030f535631fedac...
# 798    976  a3e9ba570eff338be233bf5795fb62d030f535631fedac...
#
#                                                   path  \
# 0    2f8392c2dfa63d2a7fdfebc053f9eff02246387575e205...
# 1    33f6f6793f00ed68593ce9560406006e7c9693faacccbb...
# 2    06c73d5731753b0f9accd4b68494a7b677ba8db954c7f9...
# 3    52b40bf55615a1a76458fafa29e1225c0bed5b7df0f3a4...
# 4    48081fddb6fe56d7238739344274f98f70f4a4335f37fc...
# ..                                                 ...
# 794  2afa3d37e26d4c0abccf567c24431dba4094eb3d012bea...
# 795  3382f58c3e8268ef8196df2dd123a5be9c87542f33a68f...
# 796  3775fea31d0de1fe21deb3c11d363df0776d606878adb9...
# 797  4ff1fdee808c24ac5caf5c020c3d8d6cca47f0b5d8e075...
# 798  13bf7dc8e51955c3061d23d79a43b0ce3a2b154d1fe273...
#
#                                               sentence  up_votes  down_votes  \
# 0                       We couldn't make it in a week!         2           1
# 1                        I promise, I will be careful!         2           0
# 2    Vermicelli A trio, or musical piece for three ...         2           0
# 3             Plastic surgery has become more popular.         2           0
# 4                                   I'm going to them.         3           0
# ..                                                 ...       ...         ...
# 794  Some men are standing around a grill as some a...         2           0
# 795  A woman riding a blue bike is carrying a white...         3           0
# 796               Two men skateboarding in the forest.         2           0
# 797                      Two people talking on a dock.         2           0
# 798  A crowd of variously attired people is walking...         2           0
#
#           age  gender   accent
# 0    fourties  female       us
# 1       teens  female    other
# 2    twenties  female       us
# 3    fourties  female       us
# 4    twenties  female  england
# ..        ...     ...      ...
# 794  twenties    male       us
# 795  twenties    male       us
# 796  twenties    male       us
# 797  twenties    male       us
# 798  twenties    male       us
#
# [799 rows x 9 columns]

# %%
async def extract_F0(count, row):
    async with sem:
        file = row.path + '.wav'

        file_path = os.path.join(project_root,"CommonVoice-En", "Full", file)

        if row.gender == 'female':
            gender = 0
        if row.gender == 'male': 
            gender = 1

        audio_data = parselmouth.Sound(file_path)
        pitch = audio_data.to_pitch()
        pitch_values = pitch.selected_array['frequency']
        

        nobs_pitch, minmax_pitch, mean_pitch, variance_pitch, skew_pitch, kurtosis_pitch =  stats.describe(pitch_values)
        median_pitch   = np.median(pitch_values)
        mode_pitch     = stats.mode(pitch_values).mode[0]
        std_pitch      = np.std(pitch_values)
        low_pitch,peak_pitch = minmax_pitch
        q75_pitch,q25_pitch  = np.percentile(pitch_values, [75 ,25])
        iqr_pitch      = q75_pitch - q25_pitch
        
        sample_features = [nobs_pitch, mean_pitch, skew_pitch, kurtosis_pitch, median_pitch, mode_pitch, std_pitch, low_pitch, peak_pitch, q25_pitch, q75_pitch, iqr_pitch]
        sample_features.insert(0,str(file))
        sample_features.append(gender)
        
        print(f"\r{count}/{len(df)}",end='')
        features_list.append(sample_features)
    
        return

# %%
# #Calculo de tempo de disparo
start_time = time.time()

#inicio do Loop
loop = asyncio.get_event_loop()

#Controle de requisições por vez
sem = asyncio.Semaphore(600)

#Array de tasks
sents = []

nest_asyncio.apply()

#Coleta as recomendações para envio
gender_list = []
file_list = []
features_list = []

for k, row in df.iterrows():
        sent = asyncio.ensure_future(extract_F0(count=k+1, row=row))
#         sents.append(sent)
 
# done, _ = loop.run_until_complete(asyncio.wait(sents))
# Out:
# 799/799

# %%
dataframe_features = pd.DataFrame(features_list, columns = ['FileName', 'nobs_pitch', 'mean_pitch', 'skew_pitch', 'kurtosis_pitch',
 'median_pitch', 'mode_pitch', 'std_pitch', 'low_pitch', 'peak_pitch', 'q25_pitch', 'q75_pitch', 'iqr_pitch', 'Gender'])
dataframe_features
# Out:
#                                               FileName  nobs_pitch  \
# 0    2f8392c2dfa63d2a7fdfebc053f9eff02246387575e205...         431
# 1    33f6f6793f00ed68593ce9560406006e7c9693faacccbb...         683
# 2    06c73d5731753b0f9accd4b68494a7b677ba8db954c7f9...         678
# 3    52b40bf55615a1a76458fafa29e1225c0bed5b7df0f3a4...         743
# 4    48081fddb6fe56d7238739344274f98f70f4a4335f37fc...         289
# ..                                                 ...         ...
# 794  2afa3d37e26d4c0abccf567c24431dba4094eb3d012bea...         585
# 795  3382f58c3e8268ef8196df2dd123a5be9c87542f33a68f...         525
# 796  3775fea31d0de1fe21deb3c11d363df0776d606878adb9...         292
# 797  4ff1fdee808c24ac5caf5c020c3d8d6cca47f0b5d8e075...         311
# 798  13bf7dc8e51955c3061d23d79a43b0ce3a2b154d1fe273...         740
#
#      mean_pitch  skew_pitch  kurtosis_pitch  median_pitch  mode_pitch  \
# 0     98.615796    1.205098       -0.070656      0.000000         0.0
# 1    164.199106   -0.484600       -1.620728    221.642048         0.0
# 2     84.513786    1.087563        0.093838      0.000000         0.0
# 3     35.610266    1.670144        1.343756      0.000000         0.0
# 4     88.441567    0.954049       -0.673693      0.000000         0.0
# ..          ...         ...             ...           ...         ...
# 794   55.816647    3.076425       16.631885      0.000000         0.0
# 795   60.670798   -0.080575       -1.868937     94.198815         0.0
# 796   72.324828    3.147206       12.024177     86.971694         0.0
# 797   39.720633    3.035056       17.787581      0.000000         0.0
# 798   58.304437    3.001483       16.235792      0.000000         0.0
#
#       std_pitch  low_pitch  peak_pitch  q25_pitch   q75_pitch   iqr_pitch  \
# 0    157.837535        0.0  501.104815        0.0  227.496311  227.496311
# 1    124.685260        0.0  318.332472        0.0  262.940061  262.940061
# 2    119.546447        0.0  595.106962        0.0  209.759810  209.759810
# 3     69.712168        0.0  257.954553        0.0    0.000000    0.000000
# 4    125.156519        0.0  393.420613        0.0  221.361991  221.361991
# ..          ...        ...         ...        ...         ...         ...
# 794   81.748405        0.0  587.012587        0.0  112.573291  112.573291
# 795   56.521653        0.0  157.126994        0.0  110.263473  110.263473
# 796  108.377992        0.0  571.777860        0.0  112.555066  112.555066
# 797   67.509698        0.0  546.320074        0.0  101.399882  101.399882
# 798   76.982630        0.0  556.187611        0.0  106.926435  106.926435
#
#      Gender
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 794       1
# 795       1
# 796       1
# 797       1
# 798       1
#
# [799 rows x 14 columns]

# %%
dataframe_features.to_csv('D:\dev\Speaker-Gender-Recognition\data\CommonVoice-En/F0_data.csv', index=False)
