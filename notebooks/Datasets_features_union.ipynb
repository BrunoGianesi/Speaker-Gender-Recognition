# %%
import pandas as pd
import os

# %%
dataset = 'CommonVoice-En'
project_root = os.path.dirname(os.getcwd())

# %%
Features_CETUC = pd.read_csv(f'{project_root}/data/{dataset}/Features_data.csv')
F0_CETUC = pd.read_csv(f'{project_root}/data/{dataset}/F0_data.csv')
F0_CETUC = F0_CETUC[['nobs_pitch','mean_pitch','skew_pitch','kurtosis_pitch','median_pitch','mode_pitch','std_pitch','low_pitch','peak_pitch','q25_pitch','q75_pitch','iqr_pitch']]
MFCCs_CETUC = pd.read_csv(f'{project_root}/data/{dataset}/MFCCs_data.csv')
MFCCs_CETUC = MFCCs_CETUC[['MFCC_1', 'MFCC_2', 'MFCC_3', 'MFCC_4', 'MFCC_5', 'MFCC_6', 'MFCC_7', 'MFCC_8', 'MFCC_9', 'MFCC_10',
                        'MFCC_11', 'MFCC_12', 'MFCC_13', 'MFCC_14', 'MFCC_15', 'MFCC_16', 'MFCC_17', 'MFCC_18', 'MFCC_19', 'MFCC_20']]

# %%
result = pd.concat([Features_CETUC, MFCCs_CETUC], axis=1)

result
# Out:
#                                               FileName  nobs        mean  \
# 0    2f8392c2dfa63d2a7fdfebc053f9eff02246387575e205...    66  102.348485
# 1    33f6f6793f00ed68593ce9560406006e7c9693faacccbb...   103  230.026294
# 2    06c73d5731753b0f9accd4b68494a7b677ba8db954c7f9...   103  651.933657
# 3    52b40bf55615a1a76458fafa29e1225c0bed5b7df0f3a4...   112  337.172619
# 4    48081fddb6fe56d7238739344274f98f70f4a4335f37fc...    44  139.550395
# ..                                                 ...   ...         ...
# 794  2afa3d37e26d4c0abccf567c24431dba4094eb3d012bea...    89  179.213483
# 795  3382f58c3e8268ef8196df2dd123a5be9c87542f33a68f...    80  119.812500
# 796  3775fea31d0de1fe21deb3c11d363df0776d606878adb9...    45  201.777778
# 797  4ff1fdee808c24ac5caf5c020c3d8d6cca47f0b5d8e075...    48   78.307292
# 798  13bf7dc8e51955c3061d23d79a43b0ce3a2b154d1fe273...   112  161.175595
#
#          skew   kurtosis  median   mode          std   low    peak  ...  \
# 0    4.147523  18.221901    50.0   45.0   137.119224   0.0   890.0  ...
# 1    2.706938   6.621953   105.0   95.0   316.039870  15.0  1660.0  ...
# 2    2.526111   6.171771   145.0   90.0  1096.607296   0.0  5115.0  ...
# 3    2.990574   9.371681   212.5  400.0   444.804824   0.0  2195.0  ...
# 4    6.348443  38.547236    75.0   70.0   351.816990  50.0  2440.0  ...
# ..        ...        ...     ...    ...          ...   ...     ...  ...
# 794  2.796121   6.124384    35.0   15.0   423.069242   0.0  1715.0  ...
# 795  4.037067  16.370266    42.5   15.0   279.340119   0.0  1575.0  ...
# 796  2.466445   4.207987    40.0   20.0   434.972739   0.0  1540.0  ...
# 797  5.805409  34.608072    22.5   20.0   209.769294   0.0  1445.0  ...
# 798  3.342740  10.746279    40.0   35.0   355.769597   0.0  2000.0  ...
#
#        MFCC_11   MFCC_12    MFCC_13    MFCC_14    MFCC_15    MFCC_16  \
# 0     2.856992  2.465940   5.942938   0.313347   3.104217  -2.834497
# 1    -1.243672 -1.213857   3.551892  -5.383912 -10.387132  -1.989165
# 2     8.708110 -2.791192  -7.731319  -8.188610   3.202001   0.105393
# 3     8.121335  8.818200   1.674253  -3.287812  -7.106608  -8.278183
# 4     3.420845  1.853223   0.308829  -2.777751  -6.462977  -5.243096
# ..         ...       ...        ...        ...        ...        ...
# 794  15.831507  1.974348   8.326172   2.741778   7.063979  10.189332
# 795  18.420574  6.096548  11.915752 -10.176714   4.880812   7.115240
# 796  20.541598  2.052305   6.906460  -4.149303   8.000287   9.208161
# 797  14.719273  6.019701   8.432873  -7.251087   3.890966   5.462469
# 798  20.517225  5.594449   6.302117  -7.528352   4.242444   4.101325
#
#        MFCC_17   MFCC_18    MFCC_19   MFCC_20
# 0    -0.554444  1.736628   0.561705  1.665345
# 1     2.685330 -2.035855  -5.382838  0.166376
# 2    -7.219017 -6.251872  -3.729273  0.017557
# 3    -2.637173  0.688595  -3.859376 -4.317977
# 4    -1.656487 -1.738631  -2.810475 -1.947313
# ..         ...       ...        ...       ...
# 794  -2.652470 -0.551666   3.843953  1.325541
# 795  -3.316691  6.399162   2.597431 -1.501949
# 796  -8.589908 -0.724473   8.975612  1.855020
# 797  -0.590436  5.690388   7.703315  2.319307
# 798 -11.055470  7.979992  11.354431 -2.456268
#
# [799 rows x 34 columns]

# %%
result.to_csv(f'{project_root}/data/{dataset}/Features_MFCCs_data.csv', index=False)
