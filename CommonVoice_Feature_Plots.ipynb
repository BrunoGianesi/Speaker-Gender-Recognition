# %% [markdown]
# # This notebook takes the features from the CommnVoice_Features_data.csv and create plots so we can get a better visualization of the features

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Import data from csv
#
# First, let's check out out dataframe

# %%
df = pd.read_csv('data/CommonVoice_Features_data.csv')
df.head()
# Out:
#                        FileName  nobs        mean      skew   kurtosis  \
# 0  common_voice_pt_22463085.wav    36  690.698282  1.932285   2.457627
# 1  common_voice_pt_20674023.wav    54  405.277778  6.155294  39.108235
# 2  common_voice_pt_20647381.wav    81  790.000000  2.386918   4.564075
# 3  common_voice_pt_19441151.wav    78  652.692308  2.735059   6.818192
# 4  common_voice_pt_20457023.wav   113  324.213717  5.497571  32.206693
#
#    median   mode          std   low    peak    q25     q75     iqr  Gender
# 0   270.0  135.0   883.629563  60.0  3165.0  135.0  690.00  555.00       1
# 1   277.5   60.0   939.345919   0.0  6885.0   60.0  446.25  386.25       1
# 2   165.0    0.0  1540.400381   0.0  7095.0    0.0  450.00  450.00       0
# 3   255.0    0.0  1204.639454   0.0  5625.0    0.0  390.00  390.00       1
# 4   135.0  135.0   641.262468   0.0  4995.0  120.0  390.00  270.00       1

# %% [markdown]
# ## Plot features
#
# We will now plot each sample's feature againts it's index and see if we can get some insights

# %%
scatter_x = df.index
scatter_y = df['nobs']
group = df['Gender']
cdict = {0: 'red', 2: 'blue'}

# Here we shuffle the dataframe and get just a portion of the data, to save on processing power
df_sample = df.sample(frac=1).reset_index(drop=True)
df_sample = df_sample[:30000]

# %% [markdown]
# ### Nobs and Mean plots

# %%
fig1, (ax1, ax2) = plt.subplots(1,2,figsize=(15,5))

colors = {0: 'red', 1: 'blue'}

ax1.scatter(df_sample['nobs'], df_sample.index, c=df_sample['Gender'].apply(lambda x: colors[x]),s= 5)
ax1.set(xlabel= "Nobs", ylabel= 'Index')
ax2.scatter(df_sample['mean'], df_sample.index, c=df_sample['Gender'].apply(lambda x: colors[x]),s= 5)
ax2.set(xlabel= "Mean", ylabel= 'Index')
plt.show()

# %% [markdown]
# ### Skew and Kurtosis plot

# %%
fig2, (ax3, ax4) = plt.subplots(1,2,figsize=(15,5))

colors = {0: 'red', 1: 'blue'}

ax3.scatter(df_sample['skew'], df_sample.index, c=df_sample['Gender'].apply(lambda x: colors[x]),s= 5)
ax3.set(xlabel= "Skew", ylabel= 'Index')
ax4.scatter(df_sample['kurtosis'], df_sample.index, c=df_sample['Gender'].apply(lambda x: colors[x]),s= 5)
ax4.set(xlabel= "Kurtosis", ylabel= 'Index')
plt.show()

# %% [markdown]
# ### Median and Mode plots

# %%
fig3, (ax5, ax6) = plt.subplots(1,2,figsize=(15,5))

colors = {0: 'red', 1: 'blue'}

ax5.scatter(df_sample['median'], df_sample.index, c=df_sample['Gender'].apply(lambda x: colors[x]),s= 5)
ax5.set(xlabel= "Median", ylabel= 'Index')
ax6.scatter(df_sample['mode'], df_sample.index, c=df_sample['Gender'].apply(lambda x: colors[x]),s= 5)
ax6.set(xlabel= "Mode", ylabel= 'Index')
plt.show()

# %% [markdown]
# ### STD and Low plots

# %%
fig4, (ax7, ax8) = plt.subplots(1,2,figsize=(15,5))

colors = {0: 'red', 1: 'blue'}

ax7.scatter(df_sample['std'], df_sample.index, c=df_sample['Gender'].apply(lambda x: colors[x]),s= 5)
ax7.set(xlabel= "STD", ylabel= 'Index')
ax8.scatter(df_sample['low'], df_sample.index, c=df_sample['Gender'].apply(lambda x: colors[x]),s= 5)
ax8.set(xlabel= "LOW", ylabel= 'Index')
plt.show()

# %% [markdown]
# ### Peak and Q25 plots

# %%
fig5, (ax9, ax10) = plt.subplots(1,2,figsize=(15,5))

colors = {0: 'red', 1: 'blue'}

ax9.scatter(df_sample['peak'], df_sample.index, c=df_sample['Gender'].apply(lambda x: colors[x]),s= 5)
ax9.set(xlabel= "Peak", ylabel= 'Index')
ax10.scatter(df_sample['q25'], df_sample.index, c=df_sample['Gender'].apply(lambda x: colors[x]),s= 5)
ax10.set(xlabel= "Q25", ylabel= 'Index')
plt.show()

# %% [markdown]
# ### Q75 and IQR plots

# %%
fig6, (ax11, ax12) = plt.subplots(1,2,figsize=(15,5))

colors = {0: 'red', 1: 'blue'}

ax11.scatter(df_sample['q75'], df_sample.index, c=df_sample['Gender'].apply(lambda x: colors[x]),s= 5)
ax11.set(xlabel= "Q75", ylabel= 'Index')
ax12.scatter(df_sample['iqr'], df_sample.index, c=df_sample['Gender'].apply(lambda x: colors[x]),s= 5)
ax12.set(xlabel= "IQR", ylabel= 'Index')
plt.show()
