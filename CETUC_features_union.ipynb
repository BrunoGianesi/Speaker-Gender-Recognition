# %%
import pandas as pd

# %%
dataset = 'CommonVoice'

# %%
Features_CETUC = pd.read_csv(f'data/{dataset}_F0_data.csv')
MFCCs_CETUC = pd.read_csv(f'data/{dataset}_MFCCs_data.csv')
MFCCs_CETUC = MFCCs_CETUC[['MFCC_1', 'MFCC_2', 'MFCC_3', 'MFCC_4', 'MFCC_5', 'MFCC_6', 'MFCC_7', 'MFCC_8', 'MFCC_9', 'MFCC_10',
                        'MFCC_11', 'MFCC_12', 'MFCC_13', 'MFCC_14', 'MFCC_15', 'MFCC_16', 'MFCC_17', 'MFCC_18', 'MFCC_19', 'MFCC_20']]

# %%
result = pd.concat([Features_CETUC, MFCCs_CETUC], axis=1)
result
# Out:
#                           FileName  nobs_pitch  mean_pitch  skew_pitch  \
# 0     common_voice_pt_19564750.wav         450   32.035183    0.972012
# 1     common_voice_pt_19547806.wav         354   39.350998    1.124757
# 2     common_voice_pt_21663026.wav         503   70.913316    0.793729
# 3     common_voice_pt_19435786.wav         431   44.169803    0.560495
# 4     common_voice_pt_20523845.wav         323   31.394417    0.692724
# ...                            ...         ...         ...         ...
# 6380  common_voice_pt_20523676.wav         323   44.052320    0.284520
# 6381  common_voice_pt_20473567.wav         323   50.481156    1.656095
# 6382  common_voice_pt_19441121.wav         371   33.419554    1.161243
# 6383  common_voice_pt_19331464.wav         414   60.681135    3.064202
# 6384  common_voice_pt_21830948.wav         395   74.969570    2.520734
#
#       kurtosis_pitch  median_pitch  mode_pitch   std_pitch  low_pitch  \
# 0          -0.981352           0.0         0.0   50.396068        0.0
# 1          -0.348730           0.0         0.0   62.423567        0.0
# 2           0.438292           0.0         0.0   83.491512        0.0
# 3          -1.649479           0.0         0.0   57.744707        0.0
# 4          -1.492219           0.0         0.0   43.823478        0.0
# ...              ...           ...         ...         ...        ...
# 6380       -1.790750           0.0         0.0   49.231375        0.0
# 6381        4.917845           0.0         0.0   74.884741        0.0
# 6382       -0.447605           0.0         0.0   55.791949        0.0
# 6383       11.911953           0.0         0.0   96.445136        0.0
# 6384        7.230195           0.0         0.0  120.377477        0.0
#
#       peak_pitch  ...   MFCC_11    MFCC_12    MFCC_13    MFCC_14   MFCC_15  \
# 0     128.648345  ... -5.147276  -4.790264  -3.148048 -11.349298  1.789662
# 1     196.907409  ... -0.791128  -1.642844  -1.085989  -8.547772  3.940871
# 2     427.454221  ... -8.219569   0.366784   1.684873  -0.771293  2.322885
# 3     141.789897  ... -5.786549  -2.714776  -3.263101  -9.414864  6.554432
# 4     110.330730  ... -7.319422   1.491621   6.339948  -0.048274  1.615325
# ...          ...  ...       ...        ...        ...        ...       ...
# 6380  124.045876  ... -1.862879   0.616064  11.230630  -6.571256  2.302101
# 6381  482.708168  ... -3.768104 -10.844618   7.530208  -3.417498  9.330006
# 6382  172.139233  ... -3.148822  -6.976841  -3.907001 -10.711233  4.793799
# 6383  557.972256  ... -1.109216  -4.903958   2.287570  -3.822159 -4.028573
# 6384  597.167517  ... -0.299576  -4.968216   4.832813   3.585701 -5.602854
#
#        MFCC_16   MFCC_17   MFCC_18   MFCC_19   MFCC_20
# 0    -2.626989 -4.031354  2.380071 -3.247863  0.126705
# 1    -1.830484 -5.179925 -6.208061 -0.138842 -3.191305
# 2     3.296580  5.283939  7.083309 -1.081281  0.140003
# 3    -5.984117 -5.155641 -0.190011 -1.389043 -2.611226
# 4     9.650620  4.186641  1.247566  0.515058  6.146833
# ...        ...       ...       ...       ...       ...
# 6380  6.313525  1.655639  1.875343 -4.589119  2.785368
# 6381  1.368913 -2.761627 -7.012846 -2.750060  3.237557
# 6382 -2.731998 -2.651874  0.227617 -0.100543 -1.910532
# 6383 -4.735598 -2.111121 -3.513963  2.324072 -1.202213
# 6384  6.050946 -8.651938 -0.641769  2.229258 -7.093744
#
# [6385 rows x 34 columns]

# %%
result.to_csv(f'data/{dataset}_F0_MFCCs_data.csv', index=False)
